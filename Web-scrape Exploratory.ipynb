# %%
# imports
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import re

# %% [markdown]
# ## Scrape Data

# %%
# set driver to chrome
driver = webdriver.Chrome("/Applications/chromedriver")

# %%
# go to the umphreys all things URL
url = "https://allthings.umphreys.com/setlists/"
driver.get(url)

# %%
# load the main page
content = driver.page_source
soup = BeautifulSoup(content)

# %%
shows = {}

# iterate through the years
for year in soup.findAll('a', attrs={'class':'setlistbutton btn btn-small btn-default'}):
    year_url = url + str(year.get('rel')[0]) + ".html"
    # go to year url
    driver.get(year_url)
    content = driver.page_source
    soup = BeautifulSoup(content)
    
    # scrape every show of this year
    for show in soup.findAll('section', attrs={'class':'setlist'}):
        
        # get show date and title of show
        header = show.find('h3', attrs={'class':'splashtitle'})
        date = header.find('a', attrs={'class':'setlistdate'}).findAll(text=True)[0].strip()
        title = ''.join(header.findAll(text=True)[1:]).strip()
        
        # get dictionary of setlabel to setlist for every set
        if 'Setlist Unknown (but it was probably awesome)' in str(show.findAll('p',recursive=False, text=True)):
            sets = None
        else:
            sets = {}
            for setlist in show.findAll('p',recursive=False):
                song_titles = []
                setlabel = ''.join(setlist.find('b', attrs={'class':'setlabel'}).findAll(text=True))
                setlabel = setlabel.strip().rstrip(':')
                song_titles = ''.join(''.join(setlist.findAll(text=True)).strip().split(':')[1:]).strip()
                sets[setlabel] = song_titles
        
        # get setlist meta date
        meta = ''.join(show.find('div', attrs={'class':'showmeta'}).findAll(text=True))
        
        # get the reviews (if any)
        tmp = meta.split('Reviews:')
        reviews = None if len(tmp) == 1 else tmp[1].strip()
        meta = tmp[0].strip()
        
        # remove the purchase via UMLive info (also removes reviews)
        meta = meta.split('Purchase via UMLive')[0]
        
        # get the support (if any)
        tmp = meta.split('Support:')
        support = None if len(tmp) == 1 else tmp[1].strip(' \n')
        meta = tmp[0].strip()
        
        # get the notes (if any)
        tmp = meta.split('Notes:')
        notes = None if len(tmp) == 1 else tmp[1].split('\n')
        meta = tmp[0].strip()
        
        # get the tag captions
        tags = re.split('([[]\d+[]].)',meta)[1:]
        tmp = {}
        for i in range(int(len(tags)/2)):
            tmp[tags[2*i].strip(' ][')] = tags[2*i+1]
        tags = tmp  
        
        # add show to show dictionary
        shows[date] = dict(title=title,
                           sets=sets,
                           reviews=reviews,
                           support=support,
                           notes=notes,
                           tags=tags)

# %%
# Create pandas dataframe
df = pd.DataFrame()
for date in shows:
    row = {}
    row['date'] = datetime.strptime(date, "%m.%d.%Y").date()
    row['title'] = shows[date]['title']
    if shows[date]['sets'] is not None:
        for setlist in shows[date]['sets']:
            row[setlist] = shows[date]['sets'][setlist]
    row['reviews'] = shows[date]['reviews']
    row['support'] = shows[date]['support']
    row['notes'] = str(shows[date]['notes'])
    row['tags'] = str(shows[date]['tags'])
    df = df.append(pd.DataFrame(row, index=[0]))

# %%
df.columns
# Out:
# Index(['date', 'title', 'Set 1', 'Set 2', 'Encore', 'reviews', 'support',
#        'notes', 'tags', 'One Set', 'Set 3', '2nd Encore', 'Quarter 1',
#        'Quarter 2', 'Quarter 3', 'Quarter 4', 'Overtime', '3rd Encore'],
#       dtype='object')

# %%
df = df[['date', 'title', 'support', 'notes', 'tags', 'reviews', 'One Set','Set 1', 'Set 2', 'Set 3', 'Encore', 
         '2nd Encore','3rd Encore', 'Quarter 1', 'Quarter 2', 'Quarter 3', 'Quarter 4', 'Overtime', ]]
df
# Out:
#           date                                    title       support  \
# 0   2020-01-17        Beacon Theatre, New York, NY, USA          None
# 0   2020-01-18        Beacon Theatre, New York, NY, USA          None
# 0   2020-01-19         Brooklyn Bowl, Brooklyn, NY, USA          None
# 0   2020-01-23         Penn's Peak, Jim Thorpe, PA, USA  The New Deal
# 0   2020-01-24            Stage AE, Pittsburgh, PA, USA  The New Deal
# ..         ...                                      ...           ...
# 0   1998-11-27              Elbo Room, Chicago, IL, USA          None
# 0   1998-12-09         The Factory, South Bend, IN, USA          None
# 0   1998-12-11               Martyrs', Chicago, IL, USA          None
# 0   1998-12-17         The Factory, South Bend, IN, USA          None
# 0   1998-12-18  Madison Oyster Bar, South Bend, IN, USA          None
#
#                                                 notes  \
# 0         ['Anthem was in remembrance of Neil Peart']
# 0      ['Limelight was in remembrance of Neil Peart']
# 0                                                None
# 0                                                None
# 0          ['last Tom Sawyer 02.18.2017 (264 shows)']
# ..                                                ...
# 0   ['there may have been a second set at this show']
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
#
#                                                  tags      reviews  \
# 0   {'1': 'began with More Than Words (Extreme) te...         None
# 0   {'1': 'with Bright Lights, Big City jam', '2':...         None
# 0   {'1': 'began with YYZ (Rush) tease', '2': 'wit...         None
# 0   {'1': 'with Rhiannon (Fleetwood Mac) teases', ...         None
# 0   {'1': 'debut, original; with Jake on acoustic'...         None
# ..                                                ...          ...
# 0                                                  {}         None
# 0   {'1': 'debut, Pink Floyd', '2': 'with Divided ...         None
# 0                                                  {}         None
# 0                                                  {}         None
# 0                                                  {}  1 review(s)
#
#                                               One Set  \
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0   Front Porch,  Hangover,  Phil's Farm,  Rosanna...
# 0                                                 NaN
# 0   Red Baron,  All In Time,  Down Under,  G-Song,...
# 0                                                 NaN
# 0                                                 NaN
#
#                                                 Set 1  \
# 0   Unsung Hero >  JaJunk >  Ocean Billy,  Speak U...
# 0   End of the Road >  1348 >  Crucial Taunt,  Syn...
# 0   Looks,  The Fussy Dutchman[1],  Maybe Someday ...
# 0   Plunger >  Glory,  Roctopus,  Similar Skin,  M...
# 0   Depth Charge >  Mad Love >  Rocker Part 2,  Re...
# ..                                                ...
# 0                                                 NaN
# 0   Divisions,  Red Baron,  Muff II The Revenge,  ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                                 Set 2 Set 3  \
# 0   Suxity >  JaJunk,  Breaker,  Wappy Sprayberry[...   NaN
# 0   Limelight[4],  Der Bluten Kat >  Higgins >  De...   NaN
# 0   Front Porch >  Resolution >  Front Porch[2],  ...   NaN
# 0   Night Nurse >  Ringo,  Example 1[1],  Hurt Bir...   NaN
# 0   Slacker,  The Triple Wide >  In The Black,  Sy...   NaN
# ..                                                ...   ...
# 0                                                 NaN   NaN
# 0   G-Song,  In the Flesh?[1],  Jessica[2],  Thin ...   NaN
# 0                                                 NaN   NaN
# 0                                                 NaN   NaN
# 0                                                 NaN   NaN
#
#                                      Encore 2nd Encore 3rd Encore Quarter 1  \
# 0   The Weight Around >  The Silent Type[4]        NaN        NaN       NaN
# 0                   Last Train Home >  1348        NaN        NaN       NaN
# 0      Phil's Farm >  Suxity >  Phil's Farm        NaN        NaN       NaN
# 0                                   Kashmir        NaN        NaN       NaN
# 0                                   Conduit        NaN        NaN       NaN
# ..                                      ...        ...        ...       ...
# 0                                       NaN        NaN        NaN       NaN
# 0                                       NaN        NaN        NaN       NaN
# 0                                       NaN        NaN        NaN       NaN
# 0                                       NaN        NaN        NaN       NaN
# 0                                       NaN        NaN        NaN       NaN
#
#    Quarter 2 Quarter 3 Quarter 4 Overtime
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# ..       ...       ...       ...      ...
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
# 0        NaN       NaN       NaN      NaN
#
# [2441 rows x 18 columns]

# %%
# create CSV
df.to_csv('scrape_09_25_2020.csv')

# %% [markdown]
# ## Analyze Scrape

# %%
df = pd.read_csv('scrape_09_25_2020.csv',index_col=0)

# %%
df[df.date == datetime.strptime("11.03.2006", "%m.%d.%Y").date()]
# Out:
# Empty DataFrame
# Columns: [date, title, Set 1, Set 2, Encore, reviews, support, notes, tags, One Set, Set 3, 2nd Encore, Quarter 1, Quarter 2, Quarter 3, Quarter 4, Overtime, 3rd Encore]
# Index: []

# %%
df[df.title == 'The Barrymore Theatre, Madison, WI, USA']
# Out:
#          date                                    title  \
# 0  2011-03-02  The Barrymore Theatre, Madison, WI, USA
# 0  2011-03-03  The Barrymore Theatre, Madison, WI, USA
# 0  2009-02-12  The Barrymore Theatre, Madison, WI, USA
# 0  2009-02-13  The Barrymore Theatre, Madison, WI, USA
# 0  2009-02-14  The Barrymore Theatre, Madison, WI, USA
# 0  2009-02-15  The Barrymore Theatre, Madison, WI, USA
# 0  2006-11-02  The Barrymore Theatre, Madison, WI, USA
# 0  2006-11-03  The Barrymore Theatre, Madison, WI, USA
# 0  2005-02-18  The Barrymore Theatre, Madison, WI, USA
# 0  2005-06-03  The Barrymore Theatre, Madison, WI, USA
# 0  2005-10-01  The Barrymore Theatre, Madison, WI, USA
# 0  2005-10-02  The Barrymore Theatre, Madison, WI, USA
# 0  2004-01-30  The Barrymore Theatre, Madison, WI, USA
# 0  2004-09-04  The Barrymore Theatre, Madison, WI, USA
# 0  2003-01-31  The Barrymore Theatre, Madison, WI, USA
# 0  2003-09-13  The Barrymore Theatre, Madison, WI, USA
# 0  2002-01-31  The Barrymore Theatre, Madison, WI, USA
# 0  2002-04-26  The Barrymore Theatre, Madison, WI, USA
# 0  2002-10-05  The Barrymore Theatre, Madison, WI, USA
# 0  2001-01-26  The Barrymore Theatre, Madison, WI, USA
# 0  2001-09-02  The Barrymore Theatre, Madison, WI, USA
# 0  2001-12-01  The Barrymore Theatre, Madison, WI, USA
#
#                                                Set 1  \
# 0  Phil's Farm >  Words >  Miss Tinkle's Overture...
# 0  The Fussy Dutchman,  Intentions Clear[1] >  Ge...
# 0  Slacker >  Ringo >  Slacker,  Atmosfarag[1] ->...
# 0  The Haunt >  Hajimemashite,  Prowler >  2nd Se...
# 0  August[1],  Professor Wormbog,  Syncopated Str...
# 0  Resolution[1] >  Great American[1],  Rocker[2]...
# 0  Intro >  Higgins >  Hurt Bird Bath >  Sweetnes...
# 0  Plunger,  Got Your Milk (Right Here) >  Wallet...
# 0  Hangover -> Who Knows >  Hangover,  Tribute to...
# 0  Andy's Last Beer >  Uncle Wally >  Andy's Last...
# 0  Plunger >  #5 >  The Bottom Half,  Divisions >...
# 0  Get In The Van,  Women Wine and Song >  Anchor...
# 0  Tonight I'm Gonna Rock You Tonight >  JaJunk >...
# 0  Dump City >  Ocean Billy,  Sociable Jimmy >  S...
# 0  Dump City,  Divisions[1],  Utopian Fir[2] >  I...
# 0  In The Kitchen >  Get In The Van,  Thin Air,  ...
# 0  Drums >  Jam >  Ringo >  Blue Echo,  Push the ...
# 0  Intro[1] >  Get In The Van >  Hajimemashite ->...
# 0  Intro[1] >  Kabump[2] >  Walletsworth,  Syncop...
# 0                                                NaN
# 0  Intro >  White Man's Moccasins,  The Fuzz >  P...
# 0  Tribute to the Spinal Shaft >  Water,  Hurt Bi...
#
#                                                Set 2  \
# 0  Prowler >  Syncopated Strangers,  I Am the Wal...
# 0  Divisions,  Der Bluten Kat >  Atmosfarag >  De...
# 0  The Bottom Half,  End of the Road,  Red Tape, ...
# 0  Blue Echo >  Living On a Farm[1] >  Blue Echo ...
# 0  All In Time,  Out Of Order >  Gulf Stream,  Mu...
# 0  Bridgeless >  Prophecy Now[4] >  Bridgeless,  ...
# 0  Much Obliged -> The Fuzz >  Tribute to the Spi...
# 0  All In Time -> Smell the Mitten,  Wife Soup,  ...
# 0  Atmosfarag[2] >  The Bottom Half,  Der Bluten ...
# 0  The Triple Wide -> 2x2,  Black Sabbath >  War ...
# 0  In Violation of Yes,  Higgins >  Much Obliged[...
# 0  All In Time,  Smell the Mitten,  Bad Poker[3],...
# 0  Bright Lights, Big City[2],  Uncle Wally >  Pa...
# 0  Wife Soup,  Blue Echo[1] >  Roulette,  Soul Fo...
# 0  Resolution >  Push the Pig >  Weed Rap[3] >  P...
# 0  Paradise City[3] >  Slacker[4] >  Miss Tinkle'...
# 0  Nothing Too Fancy[1],  Anchor Drops,  Dump Cit...
# 0  Last Call >  Prowler >  Kielbasa,  Dump City, ...
# 0  Sociable Jimmy[4] >  Out Of Order,  Hajimemash...
# 0                                                NaN
# 0  Get In The Van,  All In Time,  Hey Nineteen[1]...
# 0  "Jimmy Stewart"[3] -> 2x2,  Waiting Room[4],  ...
#
#                                               Encore      reviews  \
# 0                     Walletsworth,  Hot for Teacher  1 review(s)
# 0                               Wizard Burial Ground  1 review(s)
# 0                     Soul Food I[4] >  Morning Song          NaN
# 0                                                2x2          NaN
# 0                                 Preamble >  Mantis  1 review(s)
# 0              Honey Bunch[7],  A Fifth of Beethoven          NaN
# 0                                           Thin Air  1 review(s)
# 0                 Prowler >  Glory >  All In Time[4]  2 review(s)
# 0                     Great American >  Walletsworth  1 review(s)
# 0  Soul Food I[3] >  In the Hall of the Mountain ...          NaN
# 0                          The Song Remains the Same          NaN
# 0                                     All Night Long          NaN
# 0                                 Glory[4] >  2x2[5]          NaN
# 0                                  Nothing Too Fancy          NaN
# 0            Mercedes Benz[7],  Nothing Too Fancy[8]          NaN
# 0     Pearl Necklace[7] >  Rhiannon[8] >  40's Theme          NaN
# 0                       Soul Food I >  Mullet (Over)          NaN
# 0                      Home Sweet Home[6],  Roulette          NaN
# 0            Father and Son[12],  Pay the Snucka[13]          NaN
# 0                                                NaN          NaN
# 0                                     All Night Long          NaN
# 0           Andy's Last Beer >  Tomorrow Never Knows          NaN
#
#                      support  \
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0              Talkin' Shoes
# 0              Talkin' Shoes
# 0                        NaN
# 0                    OM Trio
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0                        NaN
# 0  The Spontaneous Throwdown
#
#                                                notes  \
# 0                                               None
# 0       ["last It's So Easy 04.13.2008 (338 shows)"]
# 0                                               None
# 0  ['last Memphis Underground 01.07.2006 (372 sho...
# 0                                               None
# 0  ['last Rocker 09.22.2006 (276 shows)', 'last W...
# 0                                               None
# 0                                               None
# 0  ["with The Woody Woodpecker theme (George Tibb...
# 0                                               None
# 0  ['with Mark on the Bus (Beastie Boys) quote fr...
# 0  ['with Cantina Band (from Star Wars) (John Wil...
# 0  ["last Tonight I'm Gonna Rock You Tonight 03.2...
# 0                                               None
# 0  ['with Unskinny Bop (Poison) tease before Divi...
# 0        ['with Nachos for Two tease before JaJunk']
# 0  ['Love Rollercoaster (The Ohio Players) was te...
# 0  ["Joel's solo CD Uncommon Ritual was released....
# 0                                               None
# 0                                               None
# 0  ["with Sweet Child O' Mine (Guns N' Roses) tea...
# 0  ["Nachos for Two was played for Vince's birthd...
#
#                                                 tags  \
# 0  {'1': 'with Blues for Los Angeles (Bill Frisel...
# 0               {'1': '"Jimmy Stewart" with lyrics'}
# 0  {'1': 'unfinished', '2': 'with Jeff Coffin on ...
# 0  {'1': "debut, Ali Baba's Tahini; two verses", ...
# 0  {'1': 'with Nothing Too Fancy tease', '2': 'wi...
# 0  {'1': 'with Jake and Brendan on acoustic guita...
# 0  {'1': 'with Kat\'s Tune tease; "Jimmy Stewart"...
# 0  {'1': 'with Brendan and Jake on acoustics', '2...
# 0  {'1': 'with Top Gun Anthem (Harold Faltermeyer...
# 0  {'1': 'with Muffburger Sandwich, Music for a F...
# 0  {'1': 'with Funky Monks (Red Hot Chili Peppers...
# 0  {'1': 'with Whipping Post (The Allman Brothers...
# 0  {'1': 'debut, original', '2': 'debut, original...
# 0  {'1': 'with Norwegian Wood (The Beatles) jam',...
# 0  {'1': 'with In A Silent Way (Miles Davis) teas...
# 0  {'1': 'with Refugee (Tom Petty) tease', '2': '...
# 0  {'1': "Mike and Kevin Browning modeled new Ump...
# 0  {'1': 'only Joel', '2': 'ended with Waterfalls...
# 0  {'1': 'with Der Bluten Kat teases', '2': 'with...
# 0                           {'1': 'debut, original'}
# 0  {'1': "with Sweet Child O' Mine (Guns N' Roses...
# 0  {'1': 'with Pick Your Nose tease', '2': 'with ...
#
#                                              One Set  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  August >  Nothing Too Fancy >  Andy's Last Bee...
# 0                                                NaN
# 0                                                NaN
#
#                                                Set 3         2nd Encore  \
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN  That's the Way[5]
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0  All In Time[10],  JaJunk >  Hurt Bird Bath[11]...                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
# 0                                                NaN                NaN
#
#   Quarter 1 Quarter 2 Quarter 3 Quarter 4 Overtime 3rd Encore
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
# 0       NaN       NaN       NaN       NaN      NaN        NaN
