# %%
import pandas as pd
import string
from typing import List

# %%
songs = pd.read_pickle('atu_cleaned/songs.pickle')
songs = songs.sort_values('name')

# %%
VALID_CHARS = [' '] + list(string.ascii_lowercase) + list('0123456789')
VOWELS = list('aeiou')

# https://stackoverflow.com/a/38760564
units = ["zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen"]
units.reverse()
UNITS = {units[i] : 19-i for i in range(len(units))}
tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]
TENS = {tens[i] : i for i in range(2,len(tens))}

# %%
def clean_song_name(song_name: str) -> str:
    """Return the song name after it is cleaned"""
    
    # lower case and remove invalid chars
    song_name = song_name.lower() 
    song_name = song_name.replace(' & ', ' n ')
    song_name = song_name.replace("/", ' ')
    song_name = ''.join([i for i in song_name if i in VALID_CHARS])
    
    # abbreviations
    abbreviations = {'chapter' : 'ch',
                     'cross' : 'x',
                     'avenue' : 'ave',
                     'example': 'ex',
                     'birthday': 'bday',
                     'doctor': 'dr',
                     'halloween': 'halow'}
    for k, v in abbreviations.items():
        song_name = song_name.replace(k,v)
    
    song_name = song_name.split()
    
    # word replacement abbreviations
    abbreviations = {'and' : 'n'}
    for k, v in abbreviations.items():
        song_name = replace(k, str(v), song_name)
    
    # map string numbers
    for k, v in TENS.items():
        song_name = replace(k, str(v), song_name)
    for k, v in UNITS.items():
        song_name = replace(k, str(v), song_name)
    song_name = replace('eightyfive', '85', song_name)
    song_name = replace('fortysix', '46', song_name)

    song_name = '<' + ' '.join(song_name) + '>'
    song_name = song_name.split()
    
    # roman numerals -> digits
    song_name = replace('i>', '1', song_name)
    song_name = replace('ii>', '2', song_name)
    song_name = replace('iii>', '3', song_name)
    
    song_name = ' '.join(song_name)
    song_name = song_name.strip('<>')
    
    return song_name
    
def replace(old: str, new: str, lst: List[str]) -> List[str]:
    """Replace instances of old with new in the given list."""
    return [new if x==old else x for x in lst]

# %%
# keep track of the frequency of words in english
with open('data/common_english_words.txt') as f:
    words = [w.rstrip() for w in f.readlines()]
freq = {words[i] : i for i in range(len(words))}
def word_freq(word: str) -> int:
    if word in freq:
        rank = freq[word]
    else:
        rank = len(freq)
    if word[-1] == 's':
        return min(rank, word_freq(word[:-1]))
    return rank

# keep track of the frequency of words in song names
song_names = [x for s in songs['name'] for x in clean_song_name(s).split()]
word_freq_in_names = pd.Series(song_names).value_counts().to_dict()

# %%
def generate_code(name: str, blacklist: List[str]) -> str:
    """Given a song name, try to generate a song code."""
    
    words = name.split()
    words_by_freq = sorted(words, key=lambda x: word_freq(x), reverse=True)
    words_by_name_freq = sorted(words, key=lambda x: word_freq_in_names[x])
    
    # 5 characters or less (without spaces)
    # Check if 4-5 chars before removing vowels then after
    word = name.replace(' ', '')
    if (len(word) < 6):
        return word
    else:
        code = word[0] + "".join([c for c in word[1:] if c not in VOWELS])
        if ((len(word) < 8) & (len(code) in [4,5])):
            return code
        
    # Exactly 4 or 5 numbers
    code = ''.join([i for i in name if i in '0123456789'])
    if (len(code) in [4,5]):
        return code
        
    # First five letter acronym for songs with more than 5 words
    if (len(words) > 5):
        return "".join([w[0] for w in words if word_freq(w) > 10][:5])
           
    # Contains word unique in all song names (4-5 chars)
    for word in words_by_name_freq:
        if word in blacklist: 
            continue
        if ((word_freq_in_names[word] == 1) & (len(word) in [4,5])):
            return word
    
    # Contains very unique word (4-5 chars)
    for word in words_by_freq:
        if word in blacklist: 
            continue
        if (word_freq(word) > 2000) & (len(word) in [4,5]):
            return word

    # Contains word unique in all song names (4-5 chars no vowels)
    for word in words_by_name_freq:
        if word in blacklist: 
            continue
        code = word[0] + "".join([c for c in word[1:] if c not in VOWELS])
        if ((word_freq_in_names[word] == 1) & (len(code) in [4,5])):
            return code
    
    # Contains very unique word (4-5 chars no vowels)
    for word in words_by_freq:
        if word in blacklist: 
            continue
        code = word[0] + "".join([c for c in word[1:] if c not in VOWELS])
        if ((word_freq(word) > 100) & (len(code) in [4,5])):
            return code
        
    # Acronym for songs with 4-5 words
    if (len(words) in [3,4,5]):
        return "".join([w[0] for w in words][:5])
    
    # First 5 letters of longest word
    return sorted(words, key=lambda x: len(x), reverse=True)[0].replace(" ","")[:5]

# %%
song_codes = {}
blacklist = []
for index, row in songs.iterrows():
    song_title = row['name']
    is_original = bool(row['original'])
    name = clean_song_name(song_title)    
    code = generate_code(name, blacklist)
    blacklist.append(code)
    song_codes[song_title] = code

# %%
print('%s' % len(song_codes))
print('%0.2f%%' % ((len(song_codes) / len(songs))*100) )
code_freq = pd.Series(song_codes.values()).value_counts().to_dict()
print(sum([1 for x in code_freq.values() if x == 1]))
print(sum([1 for x in code_freq.values() if x == 1]) / len(song_codes) * 100)
{k : [n for n in songs['name'] if song_codes[n] == k] for k,v in code_freq.items() if v > 1}
# Out:
# 975
# 100.00%
# 903
# 92.61538461538461
# {'rght': ["It's All Right", 'Make It Right', 'Right Off'],
#  'blck': ['Back In Black', 'Black Water', 'In The Black'],
#  'nght': ['All Night Long', 'Night Nurse', 'Still of the Night'],
#  'anthm': ['Anthem', 'Bullshit Anthem', 'The National Anthem'],
#  'thrs': ["There's No Crying In Mexico", 'Theresa'],
#  'frdm': ["Freedom of '76", "Freedom! '90"],
#  'sungl': ['Cheap Sunglasses', 'Sweet Sunglasses'],
#  'stran': ['Strangletage', 'The Stranger'],
#  'amrcn': ['Great American', "We're An American Band"],
#  'nghts': ['Ace of Long Nights', 'Hollywood Nights'],
#  'sweet': ['Home Sweet Home', 'Sweetness'],
#  'clsr': ['Closer', 'Come Closer'],
#  'wght': ['The Weight', 'The Weight Around'],
#  'alwys': ['Always Up', "She's Always a Woman"],
#  'alrig': ['Alright', "Feelin' Alright"],
#  'trpl': ['The Triple Wide', 'The Triple Wide/Robot Rock'],
#  'phils': ["Phil's 7 Nation Money Farm", "Phil's Farm"],
#  'strut': ['"Mrs Robinson\'s Strut"', 'Gut Strut'],
#  'lvng': ['Living In America', 'Living On a Farm'],
#  'brnn': ["Burnin' and Lootin'", "Burnin' for You"],
#  'chrch': ['Church', 'Take It to Church'],
#  'wrng': ['Got Me Wrong', 'You Got the Wrong Guy'],
#  'cmng': ['Coming In From the Cold', "Mama I'm Coming Home"],
#  'porch': ['Front Porch', 'Porch'],
#  'brth': ['Breathe', 'Room to Breathe'],
#  'bitch': ['Baby Bitch', 'Bitch'],
#  'bitte': ['Bittersweet Haj', 'Bittersweet Symphony'],
#  'bttm': ['Big Bottom', 'The Bottom Half'],
#  'mrnng': ['Good Morning Good Morning', 'Morning Song'],
#  'rckr': ['Rocker', 'Rocker Part 2'],
#  'grace': ['Amazing Grace', 'Graceland'],
#  'gldn': ['Golden Slumbers', 'Golden Years'],
#  'bthtb': ['Bathtub Gin', 'Fat Man in the Bathtub'],
#  'walk': ['Cemetery Walk', 'Walk']}

# %%
{v:k for (k,v) in song_codes.items()}
# Out:
# {'jake': '"Brendan & Jake switch rigs"',
#  'strut': 'Gut Strut',
#  '19': '#19',
#  '5': '#5',
#  'dont': "(Don't Fear) The Reaper",
#  'ntrt': '(Night Time Is) The Right TIme',
#  'sdb': "(Sittin' On) The Dock of the Bay",
#  'jstc': '...And Justice for All',
#  'snshn': '...And We Became Sunshine',
#  '1000': '1000 Places to See Before You Die',
#  '10th': '10th Grade',
#  '13dys': '13 Days',
#  '1348': '1348',
#  '1901': '1901 Jump',
#  '1999': '1999',
#  '2564': '25 or 6 to 4',
#  'self': '2nd Self',
#  '2x2': '2x2',
#  '316': '316',
#  'theme': "40's Theme",
#  '5wlyl': '50 Ways to Leave Your Lover',
#  '515': '5:15',
#  '930': '9:30',
#  'fifth': 'A Fifth of Beethoven',
#  'agogo': 'A Go Go',
#  'sleep': 'A Half Sleep',
#  'sprm': 'A Love Supreme',
#  'mild': 'A Mild Sedative',
#  'mdly': 'AC/DC Medley',
#  'abcb': 'Abacab',
#  'nghts': 'Hollywood Nights',
#  'kiss': 'Addicted to Kiss',
#  'afrc': 'Africa',
#  'after': 'After Midnight',
#  'odds': 'Against All Odds',
#  'ahab': 'Ahab',
#  'anfih': "Ain't No Fun (If the Homies Can't Have None)",
#  'aint': "Ain't No Sunshine",
#  'proud': "Ain't Too Proud to Beg",
#  'alexs': "Alex's House",
#  'blues': 'All Blues',
#  'ain': 'All I Need',
#  'ait': 'All In Time',
#  'nght': 'Still of the Night',
#  'ninja': 'All Things Ninja',
#  'alrig': "Feelin' Alright",
#  'alwys': "She's Always a Woman",
#  'grace': 'Graceland',
#  'ambln': 'Amble On',
#  'btfl': 'America the Beautiful',
#  'aitu': 'Anarchy in the U.K.',
#  'drops': 'Anchor Drops',
#  'andys': "Andy's Last Beer",
#  'anglr': 'Angular Momentum',
#  'brick': 'Another Brick in the Wall',
#  'abwt': 'Another Brick in the Wall/Thriller',
#  'anthm': 'The National Anthem',
#  'apmn': 'Apeman',
#  'qstns': 'Ask Me No Questions',
#  'atlst': 'At Last',
#  'atmos': 'Atmosfarag',
#  'attac': 'Attachments',
#  'wiede': 'Auf Wiedersehen',
#  'agst': 'August',
#  'auld': 'Auld Lang Syne',
#  'lllby': 'Australian Lullaby',
#  'ave': 'Avenue',
#  'onion': 'B. Onion',
#  'baba': "Baba O'Riley",
#  'bitch': 'Bitch',
#  'honey': "Baby Honey Sugar Darlin'",
#  'youre': "Baby You're A Rich Man",
#  'blck': 'In The Black',
#  'hlng': 'Back In Sexual Healing',
#  'frdy': 'Bad Friday',
#  'poker': 'Bad Poker',
#  'bib': 'Bad is Bad',
#  'jimi': 'Ballad of Jimi Hendrix',
#  'botr': 'Band on the Run',
#  'brrcd': 'Barracuda',
#  'bass': 'Bass solo',
#  'bthng': 'Bathing Digits',
#  'bthtb': 'Fat Man in the Bathtub',
#  'becau': 'Because',
#  'btl': 'Believe the Lie',
#  'bell': 'Bell Bottom Blues',
#  'jets': 'Bennie and the Jets',
#  'bttm': 'The Bottom Half',
#  'heart': 'Big Heart',
#  'poppa': 'Big Poppa',
#  'jean': 'Billie Jean',
#  'bday': 'Birthday',
#  'bitte': 'Bittersweet Symphony',
#  'hole': 'Black Hole Sun',
#  'mssh': 'Black Messiah',
#  'sbbth': 'Black Sabbath',
#  'bldy': 'Bloody Well Right',
#  'echo': 'Blue Echo',
#  'bob': 'Bob',
#  'bobs': "Bob's Cloud",
#  'bombt': 'Bombtrack',
#  'lovin': "Bonafide Lovin'",
#  'booth': 'Booth Love',
#  'born': 'Born Under a Bad Sign',
#  'brain': 'Brain Damage',
#  'brass': 'Brass In Pocket',
#  'brkr': 'Breaker',
#  'brkng': 'Breaking The Girl',
#  'brth': 'Room to Breathe',
#  'sighs': 'Bridge Of Sighs',
#  'bridg': 'Bridgeless',
#  'brght': 'Bright Lights, Big City',
#  'stomp': 'Bron-Y-Aur Stomp',
#  'brony': 'Bron-Yr-Aur',
#  'brown': 'Brown Eyed Girl',
#  'bubbl': 'Bubblehouse',
#  'bbbls': 'Bubbles',
#  'bllhd': 'Bullhead City',
#  'bulls': 'Bulls on the Bus',
#  'brnn': "Burnin' for You",
#  'brnng': 'Burning Down the House',
#  'bscll': 'Bus Call',
#  'bust': 'Bust a Move',
#  'arms': 'Call to Arms',
#  'find': "Can't Find My Way Home",
#  'cgiom': "Can't Get It Out of My Head",
#  'cant': "Can't Rock My Dream Face",
#  'stand': "Can't Stand Losing You",
#  'ctmeo': "Can't Take My Eyes Off Of You",
#  'hear': "Can't You Hear Me Knocking",
#  'cys': "Can't You See",
#  'cnry': 'Canary in a Coalmine',
#  'islnd': 'Cantaloupe Island',
#  'cntlp': 'Cantaloupe Woman',
#  'cntn': 'Cantina Band',
#  'carol': 'Carol of the Bells',
#  'carry': 'Carry That Weight',
#  'cars': 'Cars Trucks Buses',
#  'fever': 'Cat Scratch Fever',
#  'ctsht': 'Catshot',
#  'cltc': 'Celtic Alleluia',
#  'walk': 'Walk',
#  'cmtry': 'Cemetery Walk II',
#  'chmln': 'Chameleon',
#  'ch1': 'Chapter 1',
#  'ch10': 'Chapter 10',
#  'ch11': 'Chapter 11',
#  'ch12': 'Chapter 12',
#  'ch13': 'Chapter 13',
#  'ch14': 'Chapter 14',
#  'ch15': 'Chapter 15',
#  'ch16': 'Chapter 16',
#  'ch17': 'Chapter 17',
#  'ch18': 'Chapter 18',
#  'ch19': 'Chapter 19',
#  'ch2': 'Chapter 2',
#  'ch20': 'Chapter 20',
#  'ch21': 'Chapter 21',
#  'ch3': 'Chapter 3',
#  'ch4': 'Chapter 4',
#  'ch5': 'Chapter 5',
#  'ch6': 'Chapter 6',
#  'ch7': 'Chapter 7',
#  'ch8': 'Chapter 8',
#  'ch9': 'Chapter 9',
#  'chrts': 'Chariots of Fire',
#  'sungl': 'Sweet Sunglasses',
#  'chrb': 'Cherub Rock',
#  'chevr': 'Chevrolet',
#  'chcg': 'Chicago',
#  'story': "Children's Story",
#  'carne': 'Chitlins Con Carne',
#  'hlls': 'Christmas In Hollis',
#  'chris': 'Christmas Song',
#  'ctih': 'Christmas Time Is Here',
#  'chrch': 'Take It to Church',
#  'cnnmn': 'Cinnamon Girl',
#  'cissy': 'Cissy Strut',
#  'lites': 'City of Tiny Lites',
#  'clint': 'Clint Eastwood',
#  'clsr': 'Come Closer',
#  'cocai': 'Cocaine',
#  'cchs': 'Cochise',
#  'cold': 'Cold Gold',
#  'cayk': 'Come As Your Kids',
#  'mama': 'Come To Mama',
#  'tgthr': 'Come Together',
#  'numb': 'Comfortably Numb',
#  'cmng': "Mama I'm Coming Home",
#  'comma': 'Comma Later',
#  'cmptr': 'Computer "G"',
#  'cndt': 'Conduit',
#  'const': 'Constellations',
#  'contr': 'Controversy',
#  'hell': 'Cowboys from Hell',
#  'crazy': 'Crazy Fingers',
#  'xrds': 'Crossroads',
#  'taunt': 'Crucial Taunt',
#  'cruel': 'Cruel Summer',
#  'lies': 'Cummins Lies',
#  'ctff': 'Cut Off',
#  'cable': 'Cut the Cable',
#  'daffo': 'Daffodils',
#  'drigb': "Damn Right I've Got the Blues",
#  'dhd': 'Dance Hall Days',
#  'dncng': 'Dancing Days',
#  'brush': 'Dark Brush',
#  'strt': 'Dark Side of the Street',
#  'drmng': 'Day Dreaming',
#  'nurse': 'Day Nurse',
#  'dazed': 'Dazed and Confused',
#  'duks': 'Dazzey Duks',
#  'ddddd': 'De Do Do Do, De Da Da Da',
#  'dwyn': 'DeWayne',
#  'drdr': 'Dear Doctor',
#  'dear': 'Dear Lord',
#  'prdnc': 'Dear Prudence',
#  'debra': 'Debra',
#  'dee': 'Dee',
#  'deepe': 'Deeper',
#  'dmltn': 'Demolition Man',
#  'den': 'Den',
#  'depth': 'Depth Charge',
#  'bltn': 'Der Bluten Kat',
#  'dtrt': 'Detroit Rock City',
#  'dick': 'Dick in a Box',
#  'pony': 'Dig A Pony',
#  'dgtl': 'Digital Buddha',
#  'dmsn': 'Dim Sun',
#  'dio': 'Dio',
#  'dirty': 'Dirty Love',
#  'dvsns': 'Divisions',
#  'thry': 'Domino Theory',
#  'ddi': "Don't Do It",
#  'doves': "Don't Fear the Doves, Snucka",
#  'fight': "Don't Fight It",
#  'dstyg': "Don't Stop 'til You Get Enough",
#  'xtown': "Don't Stop Until Crosstown Traffic",
#  'dssr': "Don't Stop the Spirit of the Radio",
#  'frgt': "Don't You (Forget About Me)",
#  'dough': 'Dough Bro',
#  'undr': 'Down Under',
#  'downt': 'Downtrodden',
#  'flgd': 'Dr. Feelgood',
#  'drcnn': 'Draconian',
#  'team': 'Dream Team',
#  'drms': 'Dreams',
#  'drift': 'Drift Away',
#  'drink': 'Drink My Drank',
#  'tears': 'Driven to Tears',
#  'drums': 'Drums',
#  'duck': 'Duck Butter',
#  'dump': 'Dump City',
#  'eti': 'E.T.I.',
#  'east': 'East Nashville Easter',
#  'easy': 'Easy',
#  'eat': 'Eat',
#  'eclps': 'Eclipse',
#  'guess': 'Educated Guess',
#  'ewbcs': 'Elderly Woman Behind the Counter in a Small Town',
#  'elect': 'Electric Avenue',
#  'eath': 'Electric Avenue to Hell',
#  'emnnc': 'Eminence Front',
#  'tank': 'Empty the Tank',
#  'eotr': 'End of the Road',
#  'equal': 'Equal Rights',
#  'escp': 'Escape',
#  'even': "Even If You Don't",
#  'eltsd': 'Every Little Thing She Does Is Magic',
#  'rose': 'Every Rose Has Its Thorn',
#  'ex1': 'Example 1',
#  'fdr': 'FDR',
#  'ff': 'FF',
#  'fame': 'Fame',
#  'feud': 'Family Feud theme',
#  'fdryw': 'Farther Down The Road (You Will Accompany Me)',
#  'fthr': 'Father and Son',
#  'frlss': 'Fearless',
#  'word': 'Final Word',
#  'flame': 'Flamethrower',
#  'flab': 'Fly Like a Beagle',
#  'flyng': 'Flying',
#  'fool': 'Fool in the Rain',
#  'fools': "Fool's Gold",
#  'foots': 'Footsteps',
#  'forks': 'Forks',
#  '46n2': 'Forty-Six & 2',
#  'frnk': 'Frankie Zombie',
#  'tower': "Franklin's Tower",
#  'frdm': "Freedom! '90",
#  'devil': 'Friend of the Devil',
#  'ftb': 'From the Beginning',
#  'porch': 'Porch',
#  'port': 'Front Port',
#  'fcky': 'Fuck You',
#  'full': 'Full Frontal',
#  'funk': 'Funk Improv',
#  'fnkjm': 'Funk Jam',
#  'funky': 'Funky Bitch',
#  'stuff': 'Funky Stuff',
#  'gsong': 'G-Song',
#  'grbg': 'Garbage Man',
#  'gents': 'Gents',
#  'gstr': 'Gesture Under a Mitten',
#  'gtdwn': 'Get Down',
#  'gitv': 'Get In The Van',
#  'lucky': 'Get Lucky',
#  'guifl': 'Get Up (I Feel Like Being a) Sex Machine',
#  'ghost': 'Ghostbusters',
#  'juice': 'Gin and Juice',
#  'bttr': 'Girlfriend is Better',
#  'jama': 'Give It To Mama Jama',
#  'glide': 'Glide',
#  'glory': 'Glory',
#  'gth': 'Go to Hell',
#  'knob': "Gobbler's Knob",
#  'ggrnr': "God Gave Rock 'n' Roll To You II",
#  'goin': "Goin' Down Slow",
#  'clfrn': 'Going to California',
#  'gldn': 'Golden Years',
#  'gone': 'Gone for Good',
#  'mrnng': 'Morning Song',
#  'boys': "Good Ol' Boys",
#  'gtbt': 'Good Times Bad Times',
#  'gdby': 'Goodbye Blue Sky',
#  'gnvll': 'Goonville',
#  'wrng': 'You Got the Wrong Guy',
#  'milk': 'Got Your Milk (Right Here)',
#  'real': "Gravity's Real",
#  'amrcn': "We're An American Band",
#  'hlms': 'Groove Holmes',
#  'gulf': 'Gulf Stream',
#  'grgl': 'Gurgle',
#  'hajim': 'Hajimemashite',
#  'dlyd': 'Half Delayed',
#  'halow': 'Halloween theme',
#  'drugs': 'Handshake Drugs',
#  'hang': 'Hang Up Your Hang Ups',
#  'chads': 'Hanging Chads',
#  'hngvr': 'Hangover',
#  'warm': 'Happiness is a Warm Gun',
#  'happy': 'Happy Birthday',
#  'cigar': 'Have A Cigar',
#  'hymlc': 'Have Yourself a Merry Little Christmas',
#  'hns': 'Headphones & Snowcones',
#  'soul': 'Heart and Soul',
#  'hghts': 'Heights',
#  'hells': 'Hells Bells',
#  'hotw': 'Help On the Way',
#  'hltr': 'Helter Skelter',
#  'mjsty': 'Her Majesty',
#  'hey19': 'Hey Nineteen',
#  'hhwci': 'Hey, Hey What Can I Do',
#  'hggns': 'Higgins',
#  'hghwy': 'Highway to Hell',
#  'hill': 'Hill Street Blues theme',
#  'hinds': 'Hindsight',
#  'quit': 'Hit It and Quit It',
#  'hmn': 'Hold Me Now',
#  'lsly': 'Hold on Loosely',
#  'hldng': 'Holding Back the Years',
#  'home': 'Home',
#  'again': 'Home Again',
#  'sweet': 'Sweetness',
#  'bunch': 'Honey Bunch',
#  'honky': 'Honky Tonk Women',
#  'hcm': 'Hoochie Coochie Man',
#  'tchr': 'Hot for Teacher',
#  'hourg': 'Hourglass',
#  'hours': 'Hours',
#  'many': 'How Many More Times',
#  'hngr': 'Hunger Strike',
#  'hurt': 'Hurt Bird Bath',
#  'hrtn': "Hurtin' House",
#  'hystr': 'Hysteria',
#  'iah': 'I Am Hydrogen',
#  'iatby': 'I Am Trying to Break Your Heart',
#  'wlrs': 'I Am the Walrus',
#  'icgnc': "I Can't Go for That (No Can Do)",
#  'idnns': "I Don't Need No Steam Heat",
#  'igl': 'I Got Love',
#  'igyif': 'I Got You (I Feel Good)',
#  'ihitg': 'I Heard It Through the Grapevine',
#  'keep': "I Keep Forgettin'",
#  'iran': 'I Ran',
#  'ishfw': "I Still Haven't Found What I'm Looking For",
#  'lover': 'I Wanna Be Your Lover',
#  'iwyss': "I Want You (She's So Heavy)",
#  'iwyb': 'I Want You Back',
#  'drug': 'I Want a New Drug',
#  'there': "I'll Take You There",
#  'iof': "I'm On Fire",
#  'flng': "I've Got a Feeling",
#  'igntn': 'Ignition',
#  'immig': 'Immigrant Song',
#  'inblm': 'In Bloom',
#  'ktchn': 'In The Kitchen',
#  'pppt': 'In The Puppet Kitchen',
#  'vltn': 'In Violation of Yes',
#  'slnt': 'In a Silent Way',
#  'flesh': 'In the Flesh?',
#  'hmk': 'In the Hall of the Mountain King',
#  'idaks': "Infernal Dance of All Kastchei's Subjects",
#  'karma': 'Instant Karma!',
#  'clear': 'Intentions Clear',
#  'ils': 'Interstate Love Song',
#  'intro': 'Intro',
#  'dsnt': "It Doesn't Matter",
#  'iatt': "It's About That Time",
#  'rght': 'Right Off',
#  'igbln': "It's Gonna Be A Long Night",
#  'ini': "It's Not Impossible",
#  'ise': "It's So Easy",
#  'iewwk': "It's the End of the World as We Know It (And I Feel Fine)",
#  'jjnk': 'JaJunk',
#  'jam': 'Jam',
#  'frwll': 'Jamaica Farewell',
#  'jane': 'Jane Says',
#  'jpns': 'Japanese Cowboy',
#  'jared': 'Jared',
#  'hyde': 'Jekyll & Hyde',
#  'jssc': 'Jessica',
#  'jesus': 'Jesus Is Just Alright',
#  'jive': "Jive Talkin'",
#  'join': 'Join Together',
#  'jose': 'Jose',
#  'jump': 'Jump',
#  'jjwpa': "Jumpin' Jack Wedding Party (All the Time)",
#  'junct': 'Junct',
#  'jwin': 'Just What I Needed',
#  'frnd': 'Just a Friend',
#  'jag': 'Just a Gigolo',
#  'jt2ou': 'Just the Two of Us',
#  'kbmp': 'Kabump',
#  'polic': 'Karma Police',
#  'kshmr': 'Kashmir',
#  'kats': "Kat's Tune",
#  'keefe': 'Keefer',
#  'charl': 'Kid Charlemagne',
#  'klbs': 'Kielbasa',
#  'kmbl': 'Kimble',
#  'pain': 'King of Pain',
#  'kinky': 'Kinky Reggae',
#  'ddly': 'Kiss Me Deadly',
#  'kula': 'Kula',
#  'lwmn': 'L.A. Woman',
#  'grng': 'La Grange',
#  'lady': 'Lady',
#  'mdnn': 'Lady Madonna',
#  'wappy': 'Land Of Wappy',
#  'lrcny': 'Larceny',
#  'last': 'Last Call',
#  'crss': 'Last Caress',
#  'lms': 'Last Man Swerving',
#  'train': 'Last Train Home',
#  'late': 'Late in the Evening',
#  'layla': 'Layla',
#  'lbltz': 'Le Blitz',
#  'lean': 'Lean On Me',
#  'vegas': 'Leave Me Las Vegas',
#  'boots': 'Led Boots',
#  'zppln': 'Led Zeppelin Medley',
#  'lglz': 'Legalize It',
#  'lenny': 'Lenny',
#  'ltmn': "Let 'Em In",
#  'lir': 'Let It Rock',
#  'whsky': 'Let Me Go Home, Whiskey',
#  'roll': 'Let The Good Times Roll',
#  'dance': "Let's Dance",
#  'lgio': "Let's Get It On",
#  'lgc': "Let's Go Crazy",
#  'lbrty': 'Liberty Echo',
#  'stick': 'Licking Stick',
#  'drop': 'Life By the Drop',
#  'drng': 'Life During Exodus',
#  'lift': 'Lift & Separate',
#  'limel': 'Limelight',
#  'linus': 'Linus and Lucy',
#  'liqui': 'Liquid',
#  'liszt': 'Lisztomania',
#  'gift': 'Little Gift',
#  'crvtt': 'Little Red Corvette',
#  'wing': 'Little Wing',
#  'live': 'Live and Let Die',
#  'lvly': 'Lively Up Yourself',
#  'lvng': 'Living On a Farm',
#  'lodi': 'Lodi Dodi',
#  'cllng': 'London Calling',
#  'dngn': 'London Dungeon',
#  'looks': 'Looks',
#  'loose': 'Loose Ends',
#  'bail': 'Lord Bail Ship',
#  'lditb': 'Lost Due to Incompetence (Theme for a Big Green Van)',
#  '1927': 'Louisiana 1927',
#  'lucid': 'Lucid State',
#  'ltbbl': 'Luckenbach, Texas (Back to the Basics of Love)',
#  'eschr': 'M.C. Escher',
#  'mchn': 'Machine Gun',
#  'mdlv': 'Mad Love',
#  'mtm': 'Made to Measure',
#  'mail': 'Mail Package',
#  'make': 'Make Me',
#  'mkng': 'Making Flippy Floppy',
#  'mamu': 'Mamu',
#  'mntr': 'Maneater',
#  'mnts': 'Mantis',
#  'ghtts': 'Mantis Ghetts',
#  'maple': 'Maple Leaf Rag',
#  'march': 'March of the S.O.D.',
#  'moon': 'Marquee Moon',
#  'tanga': 'Masoko Tanga',
#  'maybe': 'Maybe Someday',
#  'mstrd': 'Mean Mr. Mustard',
#  'sndnc': 'Mediterranean Sundance',
#  'aisle': 'Meeting in the Aisle',
#  'mmrs': 'Memories of Home',
#  'mmphs': 'Memphis Underground',
#  'benz': 'Mercedes Benz',
#  'mercy': 'Mercy, Mercy, Mercy',
#  'bttl': 'Message in a Bottle',
#  'miami': 'Miami Virtue',
#  'mikes': "Mike's Song",
#  'miles': 'Miles Beyond',
#  'grdnk': 'Miss Gradenko',
#  'tnkls': "Miss Tinkle's Overture",
#  'mssy': 'Miss You',
#  'mixed': 'Mixed Bizness',
#  'moby': 'Moby Dick',
#  'mdrn': 'Modern Love',
#  'mondo': 'Mondo Garaj',
#  'nthng': 'Money For Nothing',
#  'mood': 'Mood for a Day',
#  'mgsrs': 'Moogasauras Rex',
#  'mthr': 'Mother',
#  'mothe': 'Motherless Children',
#  'myr': 'Move Your Rug',
#  'mvng': 'Moving In Stereo',
#  'much': 'Much Obliged',
#  'muff': 'Muff II: The Revenge',
#  'muffb': 'Muffburger Sandwich',
#  'mffn': 'Muffin Man',
#  'mlchs': "Mulche's Odyssey",
#  'over': 'Mullet (Over)',
#  'nitty': 'Muscle Shoals Nitty Gritty',
#  'fvrt': 'My Favorite Things',
#  'schl': 'My Old School',
#  'nchs': 'Nachos for Two',
#  'loser': 'National Loser Anthem',
#  'ntrl': 'Natural Mystic',
#  'nbrsk': 'Nebraska',
#  'nemo': 'Nemo',
#  'nemos': "Nemo's Fat Bottomed Good Times",
#  'nthr': 'Nether',
#  'cease': 'Never Cease',
#  'apart': 'Never Tear Us Apart',
#  'gmblr': 'Night Gambler',
#  'moves': 'Night Moves',
#  '1985': 'Nineteen Hundred and Eighty-Five Wellwishing',
#  'trix': 'Nipple Trix',
#  'cmmnt': 'No Comment',
#  'diabl': 'No Diablo',
#  'nmt': 'No More Tears',
#  'nol': 'No Ordinary Love',
#  'qrtr': 'No Quarter',
#  'nwlib': 'No Woman Let It Be',
#  'nonco': 'Non-Compliance',
#  'npnr': 'Nopener',
#  'north': 'North Route',
#  'wood': 'Norwegian Wood',
#  'fade': 'Not Fade Away',
#  'fancy': 'Nothing Too Fancy',
#  'nvmbr': 'November Walk',
#  'thang': "Nuthin' but a 'G' Thang",
#  'ocean': 'Ocean Billy',
#  'rain': 'October Rain',
#  'oesqu': 'Oesque',
#  'shena': 'Oh Shenandoah',
#  'wrld': 'Oh What a World',
#  'oywd': 'On Your Way Down',
#  'once': 'Once In a Lifetime',
#  '1': 'One',
#  'wckd': 'One More Wicked, Cruel Summer',
#  'onwrd': 'Onward & Upward',
#  'ophl': 'Ophelia',
#  'orfeo': 'Orfeo',
#  'orion': 'Orion',
#  'order': 'Out Of Order',
#  'outsh': 'Outshined',
#  'prfl': "Padgett's Profile",
#  'panam': 'Panama',
#  'pccbs': 'Papa Can Change a Blurred Stone',
#  'prds': 'Paradise City',
#  'peeps': "Partyin' Peeps",
#  'pssng': 'Passing',
#  'pthtq': 'Pathetique',
#  'ptnc': 'Patience',
#  'snck': 'Pay the Snucka',
#  'pearl': 'Pearl Necklace',
#  'peg': 'Peg',
#  'pgeby': 'Peter Gunn / Every Breath You Take',
#  'phils': "Phil's Farm",
#  'philo': 'Philosophy',
#  'physi': 'Physical',
#  'ps1cm': 'Piano Sonata #16 in C Major',
#  'pick': 'Pick Up the Pieces',
#  'nose': 'Pick Your Nose',
#  'ppln': 'Pipeline',
#  'prnhs': 'Piranhas',
#  'play': 'Play This',
#  'plngr': 'Plunger',
#  'plush': 'Plush',
#  'polyt': 'Polythene Pam',
#  'ponch': 'PonchEstrada',
#  'pooh': 'Pooh Doggie',
#  'pork': 'Pork Chop Pie',
#  'pour': 'Pour Some Sugar On Me',
#  'pow': 'Pow',
#  'pol': 'Power of Love',
#  'pos': 'Power of Soul',
#  'prmbl': 'Preamble',
#  'wrmbg': 'Professor Wormbog',
#  'proph': 'Prophecy Now',
#  'prove': 'Proverbial',
#  'prwlr': 'Prowler',
#  'punch': 'Punchable Face',
#  'strng': 'Puppet String',
#  'pull': 'Push & Pull',
#  'push': 'Push the Booth Deeper',
#  'ptp': 'Push the Pig',
#  'qbert': 'Q*Bert',
#  'rew': 'REW',
#  'rnbw': 'Rainbow Country',
#  '1235': 'Rainy Day Women #12 & 35',
#  'rmbl': 'Ramble On',
#  'rpprs': "Rapper's Delight",
#  'beret': 'Raspberry Beret',
#  'chant': 'Rastaman Chant',
#  'rymnd': 'Raymond',
#  'rbbl': 'Rebubula',
#  'red': 'Red',
#  'barch': 'Red Barchetta',
#  'baron': 'Red Baron',
#  'rdrm': 'Red Room',
#  'disco': 'Red Room Disco',
#  'rdtp': 'Red Tape',
#  'rity': "Reelin' in the Years",
#  'blanc': 'Reggatta de Blanc',
#  'rglt': 'Regulate',
#  'relea': 'Release',
#  'rmnd': 'Remind Me',
#  'rsltn': 'Resolution',
#  'rspct': 'Respect Yourself',
#  'restr': 'Restrung',
#  'rhnnn': 'Rhiannon',
#  'rhino': 'Rhinoceros',
#  'ride': 'Ride On Pony',
#  'rwm': 'Ride Wit Me',
#  'rift': 'Rift',
#  'ring': 'Ring of Fire',
#  'ringo': 'Ringo',
#  'rise': 'Rise To the Top',
#  'bird': 'Rising Bird',
#  'peopl': 'River People',
#  'rdhs': 'Roadhouse Blues',
#  'robot': 'Robot World',
#  'rnran': "Rock and Roll Ain't Noise Pollution",
#  'rnrp2': 'Rock and Roll Part 2',
#  'csbh': 'Rock the Casbah',
#  'rckr': 'Rocker Part 2',
#  'tree': "Rockin' Around the Christmas Tree",
#  'rctps': 'Roctopus',
#  'rlln': "Rollin' Stone",
#  'rondo': 'Rondo Alla Turca',
#  'root': 'Root Beer Rag',
#  'rsnn': 'Rosanna',
#  'roses': 'Roses',
#  'rltt': 'Roulette',
#  'rndbt': 'Roundabout',
#  'rxnn': 'Roxanne',
#  'rylly': "Royally Feel Like Driftin' Away",
#  'ruled': 'Ruled By Secrecy',
#  'antlp': 'Run Like An Antelope',
#  'dream': "Runnin' Down a Dream",
#  'rnnn': "Runnin' with the Devil",
#  'empty': 'Running on Empty',
#  'sbtg': 'Sabotage',
#  'estwd': 'Sad Clint Eastwood',
#  'salam': 'Salamander Strut',
#  'diego': 'San Diego Super Chargers',
#  'sfb': 'San Francisco Bay',
#  'scct': 'Santa Claus Is Coming to Town',
#  'melee': 'Scaffolding Melee',
#  'scns': 'Scenes from an Italian Restaurant',
#  'cabo': 'Se A Cabo',
#  'srch4': 'Search 4',
#  'ssns': 'Seasons',
#  'scnd': 'Second Song',
#  'seek': 'Seek and Destroy',
#  'brdgs': 'Seven Bridges Road',
#  'sxfrm': 'Sex Farm',
#  'seor': 'Señor Mouse',
#  'splhc': "Sgt. Pepper's Lonely Hearts Club Band (Reprise)",
#  'she': 'She',
#  'sctbw': 'She Came In Through The Bathroom Window',
#  'katy': 'She Caught the Katy',
#  's1yo': "She's Nineteen Years Old",
#  'shhh': 'Shhh / Peaceful',
#  'shine': 'Shine On You Crazy Diamond',
#  'shtgn': 'Shotgun',
#  'sbk': 'Show Biz Kids',
#  'showd': 'Showdown',
#  'yours': "Signed, Sealed, Delivered I'm Yours",
#  'slvr': 'Silver Machine',
#  'smlr': 'Similar Skin',
#  'gifts': 'Simple Gifts',
#  'srdk': 'Sir Duke',
#  'siriu': 'Sirius',
#  'sstr': 'Sister Christian',
#  'stc': 'Skin the Cat',
#  'skip': 'Skip',
#  'slckr': 'Slacker',
#  'sledg': 'Sledgehammer',
#  'sldng': 'Sliding Down',
#  'slipk': 'Slipknot!',
#  'slow': 'Slow',
#  'death': 'Sludge & Death',
#  'smell': 'Smell the Mitten',
#  'snake': 'Snake Juice',
#  'sfa': 'So Far Away',
#  'swht': 'So What',
#  'jimmy': 'Sociable Jimmy',
#  'solfe': 'Solfegietto',
#  'sf1': 'Soul Food I',
#  'sf2': 'Soul Food II',
#  'sf3': 'Soul Food III',
#  'sthrn': 'Southern Cross',
#  'booty': 'Space Funk Booty',
#  'oddty': 'Space Oddity',
#  'odyss': 'Space Odyssey',
#  'spain': 'Spain',
#  'spkp': 'Speak Up',
#  'spnl': 'Spinal Meningitis',
#  'sprs': 'Spires',
#  'sprts': 'Spirits in the Material World',
#  'mach': 'St. Hubbins Mach 2',
#  'stntn': 'Stanton',
#  'start': 'Start Me Up',
#  'stppn': "Steppin' Out",
#  'razor': "Steppin' Razor",
#  'stew': 'Stew Art Event',
#  'stnks': "Stinko's Ascension",
#  'stir': 'Stir It Up',
#  'grnds': 'Stomping Grounds',
#  'stone': 'Stonehenge',
#  'stop': 'Stop',
#  'stran': 'The Stranger',
#  'brdg': 'Strolling a Suspension Bridge',
#  'snkng': 'Sun King',
#  'super': 'Superstition',
#  'ssnh': 'Susanah',
#  'sssd': 'Sussudio',
#  'sxty': 'Suxity',
#  'sveng': 'Svenghali',
#  'swamp': 'Swamp Music',
#  'mine': "Sweet Child o' Mine",
#  'albm': 'Sweet Home Alabama',
#  'synch': 'Synchronicity II',
#  'synco': 'Syncopated Strangers',
#  'tpddd': 'TNT/Paranoid/Dirty Deeds Done Dirt Cheap',
#  'tma': 'Take Me Away',
#  'tmob': 'Take Me Out to the Ballgame',
#  'tmttr': 'Take Me To the River',
#  'takin': "Takin' It to the Streets",
#  'tlkng': 'Talking in Your Sleep',
#  'tango': 'Tango Mike',
#  'tchn': 'Techno Jam',
#  'tell': 'Tell Me Something Good',
#  'tmptd': 'Tempted',
#  '1yg': 'Ten Years Gone',
#  'tenth': 'Tenth Avenue Freeze-Out',
#  'thnk': 'Thank You',
#  'tyfbm': 'Thank You (Falettinme Be Mice Elf Agin)',
#  'thats': "That's All",
#  'wlwmy': "That's What Love Will Make You Do",
#  'ttw': "That's the Way",
#  'btbwy': "The Bed's Too Big Without You",
#  'chckn': 'The Chicken',
#  'tcs': 'The Christmas Song',
#  'crkd': 'The Crooked One',
#  'emprr': 'The Emperor',
#  'empr': 'The Empire State',
#  'thnd': 'The End',
#  'teen': 'The Final Teen Spirit',
#  'floor': 'The Floor',
#  'fussy': 'The Fussy Dutchman',
#  'thfzz': 'The Fuzz',
#  'tgim': 'The Girl Is Mine',
#  'gtakm': 'The Good Times Are Killing Me',
#  'ggs': 'The Great Gig in the Sky',
#  'grobe': 'The Grobe',
#  'haunt': 'The Haunt',
#  'joker': 'The Joker',
#  'linea': 'The Linear',
#  'mssg': 'The Message',
#  'ntdod': 'The Night They Drove Old Dixie Down',
#  'olbny': 'The Only Living Boy In New York',
#  'other': 'The Other Side of Things',
#  'pybck': 'The Payback',
#  'pequo': 'The Pequod',
#  'plot': 'The Plot Thickens',
#  'trs': 'The Rain Song',
#  'sfty': 'The Safety Dance',
#  'goes': 'The Show Goes On',
#  'type': 'The Silent Type',
#  'sgnf': 'The Skunk, The Goose, and The Fly',
#  'same': 'The Song Remains the Same',
#  'bnnr': 'The Star-Spangled Banner',
#  'strk': 'The Stroke',
#  'trpl': 'The Triple Wide/Robot Rock',
#  'trpr': 'The Trooper',
#  'wyrw': 'The Way You Rule the World',
#  'wght': 'The Weight Around',
#  'thela': 'Thela Hun Ginjeet',
#  'them': 'Them Bones',
#  'thrs': 'Theresa',
#  'thnr': 'Thin Air',
#  'thngs': 'Things Can Only Get Better',
#  'tmbpn': 'This Must Be the Place (Naive Melody)',
#  'crcks': 'Through the Cracks',
#  'thndr': "Thunder Kiss '65",
#  'thund': 'Thunderstruck',
#  'time': 'Time',
#  'ashes': 'Tiny Cities Made of Ashes',
#  'tnfdm': 'Tocatta and Fugue in D Minor',
#  'swyr': 'Tom Sawyer',
#  'tmrrw': 'Tomorrow Never Knows',
#  'tigry': "Tonight I'm Gonna Rock You Tonight",
#  'total': 'Total Eclipse of the Heart',
#  'track': 'Track Meet',
#  'trans': 'Transdermal Celebration',
#  'trvln': "Travelin' Man",
#  'crtns': 'Treacherous Cretins',
#  'trenc': 'Trenchtown Rock',
#  'tear': 'Triangle Tear',
#  'tribu': 'Tribulations',
#  'shaft': 'Tribute to the Spinal Shaft',
#  'tnd': 'Turn & Dub',
#  'tnr': 'Turn & Run',
#  'tid': 'Turn In Difference',
#  'zone': 'Twilight Zone',
#  '2dips': 'Two Dips',
#  'tckts': 'Two Tickets to Paradise',
#  '2ofus': 'Two of Us',
#  'uncha': 'Unchained',
#  'uncle': 'Uncle Wally',
#  'uncom': 'Uncommon',
#  'unski': 'Unskinny Bop',
#  'hero': 'Unsung Hero',
#  'untl': 'Until We Meet Again',
#  'creek': 'Up on Cripple Creek',
#  'uea': "Uptight (Everything's Alright)",
#  'upwrd': 'Upward',
#  'utpn': 'Utopian Fir',
#  'vibe': 'Vibe',
#  'vrtl': 'Virtual Insanity',
#  'vsns': 'Visions',
#  'insd': 'Voices Inside My Head',
#  'chld': 'Voodoo Child',
#  'voodo': 'Voodoo Lady',
#  'vlzvs': 'Voulez-Vous',
#  'vygr': 'Voyager',
#  'wbsh': 'Wabash',
#  'waist': 'Waist Down',
#  'wtng': 'Waiting Room',
#  'emtn': 'Walk This Sweet Funk Emotion',
#  'wtpl': 'Walk the Proud Land',
#  'wlkng': 'Walking On The Moon',
#  'walle': 'Walletsworth',
#  'wanna': "Wanna Be Startin' Somethin'",
#  'spray': 'Wappy Sprayberry',
#  'war': 'War',
#  'wrpgs': 'War Pigs',
#  'watch': 'Watch the River Flow',
#  'water': 'Water',
#  'wgtw': "We're Going to War",
#  'mass': 'Weapons of Mass Destruction',
#  'tngl': 'Web Tangle',
#  'wdrp': 'Weed Rap',
#  'wkpg': 'Weekapaug Groove',
#  'weird': 'Weird Fishes/Arpeggi',
#  'ndnt': "Well, You Needn't",
#  'wellw': 'Wellwishers',
#  'lndn': 'Werewolves of London',
#  'wnwsn': 'What Is and What Should Never Be',
#  'could': 'What We Could Get',
#  'wyn': 'What You Need',
#  'wgo': "What's Going On",
#  'wdc': 'When Doves Cry',
#  'levee': 'When the Levee Breaks',
#  'wwrdy': "When the World Is Running Down You Make the Best of What's Still Around",
#  'where': 'Where Is My Mind?',
#  'whstl': 'Whistle Kids',
#  'mans': "White Man's Moccasins",
#  'pckl': 'White Pickle',
#  'white': 'White Room',
#  'wddng': 'White Wedding',
#  'whths': 'Whitehouse Road',
#  'knws': 'Who Knows',
#  'whos': "Who's Loving You",
#  'whole': 'Whole Lotta Love',
#  'wife': 'Wife Soup',
#  'wild': 'Wild Side',
#  'pimp': 'Willie the Pimp',
#  'built': 'Winston Built the Bridge',
#  'wntr': 'Winter Wonderland',
#  'wish': 'Wish',
#  'wywh': 'Wish You Were Here',
#  'wlhfm': 'With a Little Help from My Friends',
#  'wzrd': 'Wizard Burial Ground',
#  'wine': 'Women Wine and Song',
#  'words': 'Words',
#  'livin': "Workin' for a Livin'",
#  'promo': 'XRT Xmas Promo Medley',
#  'xmas': 'Xmas at Wartime',
#  'xxplo': 'Xxplosive',
#  'yyz': 'YYZ',
#  'yoga': 'Yoga Pants',
#  'alone': 'You & You Alone',
#  'ycagw': "You Can't Always Get What You Want",
#  'blame': "You Can't Blame the Youth",
#  'ygtl': 'You Got the Love',
#  'gotta': 'You Gotta Move',
#  'ykwim': 'You Know What I Mean',
#  'yngmy': 'You Never Give Me Your Money',
#  'ynsyb': "You'll Need Somebody on Your Bond",
#  'young': 'Young Lust',
#  'ones': 'Zeroes & Ones'}

# %%
pd.Series([len(x) for x in song_codes.values()]).value_counts()
# Out:
# 5    482
# 4    407
# 3     82
# 1      2
# 2      2
# dtype: int64
