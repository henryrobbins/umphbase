# %%
import pandas as pd
import string
from typing import List

# %%
import codes
songs = pd.read_pickle('atu_cleaned/songs.pickle')
codes = codes.generate(songs, 5)
songs['code'] = songs['name'].map(codes)
songs
# Out:
#     song_id                                   name  \
# 0         2                                     #5
# 1         3                                13 Days
# 2         4                               2nd Self
# 3         5                                    2x2
# 4         6                             40's Theme
# ..      ...                                    ...
# 970    1050                              Footsteps
# 971    1052                 We're An American Band
# 972    1054                               Restrung
# 973    1055  This Must Be the Place (Naive Melody)
# 974    1056                     Dazed and Confused
#
#                                     slug      original_artist original   code
# 0                                      5      Umphrey's McGee        1      5
# 1                                13-days      Umphrey's McGee        1  13DYS
# 2                               2nd-self      Umphrey's McGee        1   SLF2
# ...

# %%
codes
# Out:
# {'#5': '5',
#  '13 Days': '13DYS',
#  '2nd Self': 'SLF2',
#  '2x2': '2X2',
#  "40's Theme": 'THM40',
#  "Alex's House": 'ALXS',
#  'All In Time': 'TIME',
#  'All Things Ninja': 'THNGS',
#  'Anchor Drops': 'ANCHR',
#  "Andy's Last Beer": 'ANDYS',
#  'Atmosfarag': 'ATMOS',
#  'August': 'AGST',
#  'Bad Poker': 'POKER',
#  'Believe the Lie': 'BELIE',
#  'Blue Echo': 'ECHO',
#  'Booth Love': 'BOOTH',
#  'Bridgeless': 'BRIDG',
#  'Bright Lights, Big City': 'BRGHT',
#  'Bullhead City': 'BLLHD',
#  'Cemetery Walk': 'CMTRY',
#  'Cemetery Walk II': 'WLK2',
#  'Conduit': 'CNDT',
#  'Day Nurse': 'NURSE',
#  'Dear Lord': 'DEAR',
#  'Deeper': 'DEEPE',
#  'Der Bluten Kat': 'BLTN',
#  'Dim Sun': 'DMSN',
#  'Divisions': 'DVSNS',
#  'Domino Theory': 'THRY',
#  'Dump City': 'DUMP',
#  'Eat': 'EAT',
#  'End of the Road': 'EOTR',
#  'Example 1': 'EX1',
#  'FF': 'FF',
#  'Forks': 'FORKS',
#  'Front Porch': 'PRCH',
#  'Get In The Van': 'GITV',
#  'Glory': 'GLORY',
#  'Go to Hell': 'HELL',
# ...
